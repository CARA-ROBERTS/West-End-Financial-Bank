# %% [markdown]
# # Playground for Credit Crunch Application

# %%
# Loading data in from raw csv
import pandas as pd
raw_df = pd.read_csv('../datasets/Credit_Data_Raw.csv')
raw_df
# Out:
#      CHK_ACCT  DURATION  HISTORY  NEW_CAR  USED_CAR  FURNITURE  RADIO_TV  \
# 0           0         6        4        0         0          0         1
# 1           1        48        2        0         0          0         1
# 2           3        12        4        0         0          0         0
# 3           0        42        2        0         0          1         0
# 4           0        24        3        1         0          0         0
# ..        ...       ...      ...      ...       ...        ...       ...
# 995         3        12        2        0         0          1         0
# 996         0        30        2        0         1          0         0
# 997         3        12        2        0         0          0         1
# 998         0        45        2        0         0          0         1
# 999         1        45        4        0         1          0         0
#
#      EDUCATION  RETRAINING  AMOUNT  ...  AGE  OTHER_INSTALL  RENT  OWN_RES  \
# 0            0           0    1169  ...   67              0     0        1
# 1            0           0    5951  ...   22              0     0        1
# 2            1           0    2096  ...   49              0     0        1
# 3            0           0    7882  ...   45              0     0        0
# 4            0           0    4870  ...   53              0     0        0
# ..         ...         ...     ...  ...  ...            ...   ...      ...
# 995          0           0    1736  ...   31              0     0        1
# 996          0           0    3857  ...   40              0     0        1
# 997          0           0     804  ...   38              0     0        1
# 998          0           0    1845  ...   23              0     0        0
# 999          0           0    4576  ...   27              0     0        1
#
#      NUM_CREDITS  JOB  NUM_DEPENDENTS  TELEPHONE  FOREIGN  DEFAULT
# 0              2    2               1          1        0        0
# 1              1    2               1          0        0        1
# 2              1    1               2          0        0        0
# 3              1    2               2          0        0        0
# 4              2    2               2          0        0        1
# ..           ...  ...             ...        ...      ...      ...
# 995            1    1               1          0        0        0
# 996            1    3               1          1        0        0
# 997            1    2               1          0        0        0
# 998            1    2               1          1        0        1
# 999            1    2               1          0        0        0
#
# [1000 rows x 31 columns]

# %% [markdown]
# # Model-Prediction Function

# %%
def credit_crunch(converted_data,  return_evaluation=False, model_type=False):
# Credit Crunch is a TensorFlow Neural Network that predicts an applicant's probablity to default on a loan. 
# If default is predicted, a loan denial is returned; otherwise, approved.
# The NN model is dynamically created everytime to match in input data that is imported as a key:value dictionary.
# return_evaluation should be a boolean value (true/false) on whether or not to return model evaluation metrics with function
# Generic NN model parameters can be set in the DEV TOOLS.


    ### DEV TOOLS ###
    return_model_evaluation = return_evaluation
    numpy_seed = 42
    number_inputs = len(converted_data)
    number_classes = 2
    number_hidden_layers = 1
    number_hidden_nodes = number_inputs * (50/30)
    number_epochs = 10
    layer_activation = 'relu'
    classifier_activation = 'softmax'
    learn_metrics = ['accuracy']
    loss_type = 'categorical_crossentropy'
    optimizer_type = 'adam'

    # import dependencies
    import numpy as np
    import pandas as pd
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import LabelEncoder, MinMaxScaler
    from tensorflow.keras.utils import to_categorical
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense



    # setting numpy seed for reproducible results
    np.random.seed(numpy_seed)


    # import train data
    raw_data = pd.read_csv('datasets/Credit_Data_Raw.csv')

    raw_data.dropna()
    
    # defining labels, input fields, and input form data
    X = raw_data.drop('DEFAULT', axis=1)[[item for item in converted_data]]
    y = np.array(raw_data['DEFAULT']).reshape(-1, 1)
    data_bundle = np.array(list([converted_data[item] for item in converted_data])).reshape(1, -1)
    
    # spliting data to test and training sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    
    # creating scaler data 
    X_scaler = MinMaxScaler().fit(X_train)

    
    
    # loading pre-defined model
    if model_type:
        
        from tensorflow.keras.models import load_model

        model = load_model("models/DEFAULT_model_trained_top_10.h5")
        
        model_loss = 0.5177
        model_accuracy = 0.7680
    
    
    
    # creating dynamic model based on passed data bundle
    else:
        
        # scaling data 
        X_train_scaled = X_scaler.transform(X_train)
        X_test_scaled = X_scaler.transform(X_test)
        
        
        # one-hot-encoding labels
        label_encoder = LabelEncoder()
        label_encoder.fit(y_train)
        encoded_y_train = label_encoder.transform(y_train)
        encoded_y_test = label_encoder.transform(y_test)
        y_train_categorical = to_categorical(encoded_y_train)
        y_test_categorical = to_categorical(encoded_y_test)
        
        
        # instantiating Neural Net Model
        model = Sequential()

        # adding input layer
        model.add(Dense(units=number_hidden_nodes, activation=layer_activation, input_dim=number_inputs))

        # adding hidden layers
        for layer in np.arange(0, number_hidden_layers):
            model.add(Dense(units=number_hidden_nodes, activation=layer_activation))

        # adding classifier layer
        model.add(Dense(units=number_classes, activation=classifier_activation))

        # compiling model
        model.compile(optimizer=optimizer_type, loss=loss_type, metrics=learn_metrics)

        # fitting model to training data
        model.fit(
            X_train_scaled,
            y_train_categorical,
            epochs=number_epochs,
            shuffle=True,
            verbose=0
        )
    
        # evaluating dynamic model
        model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose=0)

    # scaling data bundle
    data_bundle_scaled = X_scaler.transform(data_bundle)
    
    # predicting approval for user (1st # is Approval Probability or 2nd # is Default Probability)
    crunchies = model.predict(data_bundle_scaled)

    
    # returning model evaluation if turned on
    if return_model_evaluation:
        
        return crunchies, model_loss, model_accuracy
    
    else:
    
        return crunchies

# %% [markdown]
# # Approval Check Function

# %%
def approval_check(crunchies, model_accuracy):
# approval_check determines the approval status of an applicant based on the approval probability and determining model accuracy
    
    # hard coding approval status variables
    sufficient_accuracy = 0.75
    approved_probability = 0.5

    # extracting approval probability from crunchies (class prediction probabilities); 
    # 1st value, [0], is approval probabilty
    # 2nd value, [1], is default probability
    approval_probability = crunchies[0][0]

        
    if model_accuracy > sufficient_accuracy:
        if approval_probability >= approved_probability:
            return("Approval")
        else:
            return('Declined')

    else:
        if approval_probability >= approved_probability:
            return('Declined')
        else:
            return('Approval')

# %% [markdown]
# # Creating Synthetic Data Bundles from provided dataset

# %%
# This cell grabs the first # rows (dp_count) and packages them so they can be input into the function
import numpy as np

dp_count = 100
dp_list = []
for item in np.arange(0, dp_count):
    t1 = raw_df.drop('DEFAULT', axis=1).iloc[item]
    dp = {}
    
    for index, item in enumerate(raw_df.columns.drop(['DEFAULT'])):
        dp[item] = t1[index]
    dp_list.append(dp)
dp_list
# Out:
# [{'CHK_ACCT': 0,
#   'DURATION': 6,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1169,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 67,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 48,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 5951,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 22,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 1,
#   'RETRAINING': 0,
#   'AMOUNT': 2096,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 49,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 42,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 7882,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 1,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 45,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 24,
#   'HISTORY': 3,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 4870,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 53,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 36,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 1,
#   'RETRAINING': 0,
#   'AMOUNT': 9055,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 35,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 24,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2835,
#   'SAV_ACCT': 2,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 53,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 36,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 6948,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 35,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 3059,
#   'SAV_ACCT': 3,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 1,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 61,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 30,
#   'HISTORY': 4,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 5234,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 0,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 1,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 28,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1295,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 25,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 48,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 4308,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 24,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1567,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 22,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 24,
#   'HISTORY': 4,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1199,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 60,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 15,
#   'HISTORY': 2,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1403,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 28,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 24,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1282,
#   'SAV_ACCT': 1,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 32,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 24,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2424,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 53,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 30,
#   'HISTORY': 0,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 8072,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 25,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 3,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 24,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 12579,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 44,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 24,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 3430,
#   'SAV_ACCT': 2,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 31,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 9,
#   'HISTORY': 4,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2134,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 48,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 3,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 6,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2647,
#   'SAV_ACCT': 2,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 44,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 10,
#   'HISTORY': 4,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2241,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 48,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 0,
#   'FOREIGN': 1},
#  {'CHK_ACCT': 1,
#   'DURATION': 12,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1804,
#   'SAV_ACCT': 1,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 44,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 10,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2069,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 1,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 26,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 1},
#  {'CHK_ACCT': 0,
#   'DURATION': 6,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1374,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 36,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 6,
#   'HISTORY': 0,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 426,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 1,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 39,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 2,
#   'DURATION': 12,
#   'HISTORY': 1,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 409,
#   'SAV_ACCT': 3,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 42,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 7,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2415,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 1,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 34,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 60,
#   'HISTORY': 3,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 6836,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 63,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 18,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 1913,
#   'SAV_ACCT': 3,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 1,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 36,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 24,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 4020,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 27,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 18,
#   'HISTORY': 2,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 5866,
#   'SAV_ACCT': 1,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 30,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 1264,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 57,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 2,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1474,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 33,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 45,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 4746,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 25,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 48,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 1,
#   'RETRAINING': 0,
#   'AMOUNT': 6110,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 31,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 2,
#   'DURATION': 18,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2100,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 1,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 37,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 2,
#   'DURATION': 10,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1225,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 37,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 9,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 458,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 24,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 30,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2333,
#   'SAV_ACCT': 2,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 30,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1158,
#   'SAV_ACCT': 2,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 1,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 26,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 18,
#   'HISTORY': 3,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 6204,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 44,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 30,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 6187,
#   'SAV_ACCT': 1,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 1,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 24,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 48,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 6143,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 58,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 11,
#   'HISTORY': 4,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1393,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 35,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 36,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2299,
#   'SAV_ACCT': 2,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 39,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 6,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1352,
#   'SAV_ACCT': 2,
#   'EMPLOYMENT': 0,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 23,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 0,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 11,
#   'HISTORY': 4,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 7228,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 39,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2073,
#   'SAV_ACCT': 1,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 1,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 28,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 24,
#   'HISTORY': 3,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2333,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 29,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 27,
#   'HISTORY': 3,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 5965,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 30,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1262,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 25,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 18,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 3378,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 31,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 36,
#   'HISTORY': 3,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2225,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 57,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 6,
#   'HISTORY': 1,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 783,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 1,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 26,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 6468,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 0,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 52,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 36,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 9566,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 31,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 2,
#   'DURATION': 18,
#   'HISTORY': 2,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1961,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 23,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 36,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 6229,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 1,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 23,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 9,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 1391,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 1,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 27,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 15,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1537,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 1,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 50,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 36,
#   'HISTORY': 0,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 1953,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 61,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 48,
#   'HISTORY': 0,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 14421,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 25,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 24,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 3181,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 26,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 27,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 5190,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 48,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 4,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2171,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 29,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1007,
#   'SAV_ACCT': 3,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 1,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 22,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 36,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 1,
#   'RETRAINING': 0,
#   'AMOUNT': 1819,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 37,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 36,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2394,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 25,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 36,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 8133,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 30,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 7,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 730,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 46,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 8,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1164,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 51,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 42,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 5954,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 41,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 36,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 1,
#   'RETRAINING': 0,
#   'AMOUNT': 1977,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 40,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 12,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1526,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 66,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 42,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 3965,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 34,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 11,
#   'HISTORY': 3,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 4771,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 51,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 54,
#   'HISTORY': 0,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 9436,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 39,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 30,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 3832,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 2,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 1,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 22,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 24,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 5943,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 44,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 15,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1213,
#   'SAV_ACCT': 2,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 47,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 18,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 1568,
#   'SAV_ACCT': 1,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 24,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 24,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1755,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 1,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 58,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 10,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2315,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 52,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 1412,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 1,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 29,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 18,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1295,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 1,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 27,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 36,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 1,
#   'RETRAINING': 0,
#   'AMOUNT': 12612,
#   'SAV_ACCT': 1,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 1,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 47,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 18,
#   'HISTORY': 2,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2249,
#   'SAV_ACCT': 1,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 30,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 12,
#   'HISTORY': 0,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1108,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 28,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 618,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 56,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 0,
#   'DURATION': 12,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1409,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 54,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 797,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 3,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 33,
#   'OTHER_INSTALL': 1,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 1,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 2,
#   'DURATION': 24,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 1,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 3617,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 1,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 20,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 12,
#   'HISTORY': 2,
#   'NEW_CAR': 1,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 1318,
#   'SAV_ACCT': 3,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 54,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 54,
#   'HISTORY': 0,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 15945,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 1,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 1,
#   'AGE': 58,
#   'OTHER_INSTALL': 0,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 1,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 3,
#   'DURATION': 12,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 1,
#   'RETRAINING': 0,
#   'AMOUNT': 2012,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 0,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 2,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 61,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 18,
#   'HISTORY': 2,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 1,
#   'AMOUNT': 2622,
#   'SAV_ACCT': 1,
#   'EMPLOYMENT': 2,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 34,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 36,
#   'HISTORY': 4,
#   'NEW_CAR': 0,
#   'USED_CAR': 0,
#   'FURNITURE': 0,
#   'RADIO_TV': 1,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 2337,
#   'SAV_ACCT': 0,
#   'EMPLOYMENT': 4,
#   'INSTALL_RATE': 4,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 1,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 36,
#   'OTHER_INSTALL': 0,
#   'RENT': 0,
#   'OWN_RES': 1,
#   'NUM_CREDITS': 1,
#   'JOB': 2,
#   'NUM_DEPENDENTS': 1,
#   'TELEPHONE': 0,
#   'FOREIGN': 0},
#  {'CHK_ACCT': 1,
#   'DURATION': 20,
#   'HISTORY': 3,
#   'NEW_CAR': 0,
#   'USED_CAR': 1,
#   'FURNITURE': 0,
#   'RADIO_TV': 0,
#   'EDUCATION': 0,
#   'RETRAINING': 0,
#   'AMOUNT': 7057,
#   'SAV_ACCT': 4,
#   'EMPLOYMENT': 3,
#   'INSTALL_RATE': 3,
#   'MALE_DIV': 0,
#   'MALE_SINGLE': 1,
#   'MALE_MAR_or_WID': 0,
#   'CO_APPLICANT': 0,
#   'GUARANTOR': 0,
#   'PRESENT_RESIDENT': 4,
#   'REAL_ESTATE': 0,
#   'PROP_UNKN_NONE': 0,
#   'AGE': 36,
#   'OTHER_INSTALL': 1,
#   'RENT': 1,
#   'OWN_RES': 0,
#   'NUM_CREDITS': 2,
#   'JOB': 3,
#   'NUM_DEPENDENTS': 2,
#   'TELEPHONE': 1,
#   'FOREIGN': 0}]

# %% [markdown]
# # Looping through Data Bundles for Evaluation

# %%
# This cell takes the dp_list from previous cell and loops through them, predicting 1 at a time (like our app will)
tests_df = pd.DataFrame(columns={'Actual', 'Result', 'MA', 'ML', 'Approval_Prob'})

for index, item in enumerate(dp_list):
    print(f'Number of Inputs:{len(item)}')
    test, ml, ma= credit_crunch(item, True, False)
    actual = df['DEFAULT'][index]
    results = approval_check(test, ma)
    print(actual, test, results, ma, ml)
    
    current_test= pd.DataFrame({'Actual':[actual], 'Result':[results], 'MA':[ma], 'ML':[ml], 'Approval_Prob':[test[0][0]]})
    tests_df = tests_df.append(current_test)
#     tests_df.to_csv('datasets/approval.csv')
# Out:
# Number of Inputs:30
# 0 [[0.98193604 0.018064  ]] Approval 0.764 0.4769752697944641
# Number of Inputs:30
# 1 [[0.61136353 0.38863647]] Approval 0.772 0.4779868814945221
# Number of Inputs:30
# 0 [[0.96448886 0.0355112 ]] Approval 0.764 0.46832211685180664
# Number of Inputs:30
# 0 [[0.49976784 0.50023216]] Declined 0.784 0.4799963989257813
# Number of Inputs:30
# 1 [[0.19343334 0.80656666]] Approval 0.744 0.49181829047203063
# Number of Inputs:30
# 0 [[0.77025425 0.2297458 ]] Approval 0.764 0.47376262593269347
# Number of Inputs:30
# 0 [[0.8938669  0.10613316]] Declined 0.748 0.5041798486709594
# Number of Inputs:30
# 0 [[0.6300898  0.36991012]] Approval 0.772 0.4734583866596222
# Number of Inputs:30
# 0 [[0.97868836 0.02131168]] Approval 0.78 0.47456085205078125
# Number of Inputs:30
# 1 [[0.20986351 0.7901365 ]] Declined 0.764 0.4734839415550232
# Number of Inputs:30
# 1 [[0.2957965 0.7042034]] Declined 0.784 0.450181901216507
# Number of Inputs:30
# 1 [[0.15413694 0.84586304]] Declined 0.78 0.4700547568798065
# Number of Inputs:30
# 0 [[0.7005006  0.29949936]] Approval 0.8 0.46929905271530153
# Number of Inputs:30
# 1 [[0.5512558  0.44874418]] Approval 0.76 0.4718446509838104
# Number of Inputs:30
# 0 [[0.30185884 0.69814116]] Declined 0.78 0.4765595998764038
# Number of Inputs:30
# 1 [[0.50221163 0.49778828]] Declined 0.748 0.48519167375564576
# Number of Inputs:30
# 0 [[0.97933036 0.0206696 ]] Approval 0.752 0.4877592520713806
# Number of Inputs:30
# 0 [[0.34472764 0.6552723 ]] Approval 0.732 0.5004245760440826
# Number of Inputs:30
# 1 [[0.36259693 0.637403  ]] Declined 0.776 0.46283547949790954
# Number of Inputs:30
# 0 [[0.9674503  0.03254964]] Approval 0.776 0.47799180150032045
# Number of Inputs:30
# 0 [[0.9224069  0.07759316]] Approval 0.772 0.47888055324554446
# Number of Inputs:30
# 0 [[0.83124703 0.168753  ]] Declined 0.748 0.4737183403968811
# Number of Inputs:30
# 0 [[0.91244507 0.08755495]] Approval 0.776 0.4673377313613892
# Number of Inputs:30
# 0 [[0.9483758  0.05162412]] Approval 0.78 0.4798692247867584
# Number of Inputs:30
# 0 [[0.989195   0.01080501]] Approval 0.788 0.47286904096603394
# Number of Inputs:30
# 0 [[0.840224 0.159776]] Approval 0.772 0.46982417035102847
# Number of Inputs:30
# 0 [[0.8846327  0.11536729]] Approval 0.764 0.4732216362953186
# Number of Inputs:30
# 0 [[0.8490548  0.15094523]] Approval 0.764 0.48931733942031863
# Number of Inputs:30
# 0 [[0.92386603 0.076134  ]] Approval 0.776 0.472082878112793
# Number of Inputs:30
# 1 [[0.24436222 0.75563776]] Declined 0.764 0.4649178853034973
# Number of Inputs:30
# 0 [[0.5881342 0.4118657]] Approval 0.78 0.47651557517051696
# Number of Inputs:30
# 0 [[0.47797745 0.5220225 ]] Declined 0.78 0.47643757343292237
# Number of Inputs:30
# 0 [[0.615557 0.384443]] Approval 0.792 0.47127668714523313
# Number of Inputs:30
# 0 [[0.958903   0.04109696]] Approval 0.76 0.4783148698806763
# Number of Inputs:30
# 0 [[0.65670025 0.34329978]] Approval 0.772 0.4755153591632843
# Number of Inputs:30
# 1 [[0.41395864 0.58604133]] Approval 0.748 0.4757358508110046
# Number of Inputs:30
# 0 [[0.7416888  0.25831115]] Approval 0.768 0.4711333305835724
# Number of Inputs:30
# 1 [[0.6984112  0.30158877]] Approval 0.776 0.4797681822776794
# Number of Inputs:30
# 0 [[0.8703744  0.12962559]] Approval 0.776 0.4735046002864838
# Number of Inputs:30
# 0 [[0.81930476 0.18069525]] Approval 0.772 0.4726843674182892
# Number of Inputs:30
# 0 [[0.86272156 0.13727845]] Approval 0.78 0.47557505989074705
# Number of Inputs:30
# 0 [[0.77644473 0.22355533]] Approval 0.768 0.4682502589225769
# Number of Inputs:30
# 0 [[0.89311326 0.10688681]] Approval 0.788 0.47319636631011963
# Number of Inputs:30
# 0 [[0.72626776 0.27373222]] Approval 0.772 0.4814800362586975
# Number of Inputs:30
# 1 [[0.368744  0.6312559]] Declined 0.76 0.4876785974502563
# Number of Inputs:30
# 0 [[0.83510053 0.16489945]] Approval 0.78 0.4568845136165619
# Number of Inputs:30
# 0 [[0.92412126 0.07587873]] Approval 0.772 0.4740427803993225
# Number of Inputs:30
# 0 [[0.87953335 0.12046663]] Approval 0.752 0.4692833597660065
# Number of Inputs:30
# 0 [[0.9501476  0.04985237]] Declined 0.736 0.4773072235584259
# Number of Inputs:30
# 0 [[0.83103555 0.16896445]] Declined 0.748 0.4871180467605591
# Number of Inputs:30
# 0 [[0.8069773 0.1930228]] Approval 0.78 0.49052610278129577
# Number of Inputs:30
# 0 [[0.916132 0.083868]] Approval 0.768 0.4676756432056427
# Number of Inputs:30
# 0 [[0.91677946 0.08322056]] Approval 0.756 0.4695436680316925
# Number of Inputs:30
# 0 [[0.96107394 0.03892604]] Approval 0.768 0.4777141716480255
# Number of Inputs:30
# 1 [[0.2771387 0.7228613]] Declined 0.76 0.47042122316360474
# Number of Inputs:30
# 0 [[0.9350036  0.06499637]] Approval 0.776 0.4563311719894409
# Number of Inputs:30
# 1 [[0.7456578  0.25434217]] Approval 0.792 0.4530314450263977
# Number of Inputs:30
# 0 [[0.7482544 0.2517455]] Approval 0.772 0.4727539532184601
# Number of Inputs:30
# 0 [[0.4669902  0.53300977]] Declined 0.756 0.4850603985786438
# Number of Inputs:30
# 1 [[0.4108721 0.5891279]] Declined 0.768 0.4833223030567169
# Number of Inputs:30
# 0 [[0.5488071  0.45119292]] Approval 0.792 0.45898684406280515
# Number of Inputs:30
# 0 [[0.9845537  0.01544628]] Approval 0.756 0.49382275438308715
# Number of Inputs:30
# 1 [[0.3769996  0.62300044]] Declined 0.78 0.47339910101890564
# Number of Inputs:30
# 1 [[0.1745099 0.8254901]] Declined 0.76 0.48470198011398313
# Number of Inputs:30
# 0 [[0.7648644  0.23513566]] Declined 0.748 0.4796854434013367
# Number of Inputs:30
# 0 [[0.8974522  0.10254785]] Approval 0.772 0.48534571075439453
# Number of Inputs:30
# 0 [[0.7844976  0.21550246]] Approval 0.768 0.4764431700706482
# Number of Inputs:30
# 0 [[0.60259956 0.3974004 ]] Approval 0.784 0.4710320162773132
# Number of Inputs:30
# 1 [[0.3379786 0.6620214]] Declined 0.768 0.47735777163505555
# Number of Inputs:30
# 0 [[0.90467346 0.09532654]] Approval 0.768 0.47045068120956424
# Number of Inputs:30
# 0 [[0.8263471 0.1736529]] Approval 0.772 0.4725452663898468
# Number of Inputs:30
# 0 [[0.9696793  0.03032078]] Approval 0.78 0.4503060464859009
# Number of Inputs:30
# 0 [[0.53930855 0.46069148]] Approval 0.784 0.47545715379714965
# Number of Inputs:30
# 0 [[0.7362501  0.26374987]] Approval 0.772 0.47204269099235535
# Number of Inputs:30
# 1 [[0.31792337 0.68207663]] Declined 0.756 0.4713646733760834
# Number of Inputs:30
# 0 [[0.64054114 0.35945883]] Approval 0.756 0.4889237427711487
# Number of Inputs:30
# 1 [[0.266899   0.73310095]] Declined 0.764 0.485825199842453
# Number of Inputs:30
# 0 [[0.90459716 0.09540281]] Approval 0.768 0.4816625814437866
# Number of Inputs:30
# 0 [[0.8623762  0.13762383]] Declined 0.72 0.49808877682685854
# Number of Inputs:30
# 0 [[0.5690895  0.43091056]] Approval 0.784 0.4707583236694336
# Number of Inputs:30
# 1 [[0.93387365 0.06612629]] Approval 0.768 0.48160532450675964
# Number of Inputs:30
# 0 [[0.95951897 0.040481  ]] Approval 0.792 0.46124828600883483
# Number of Inputs:30
# 0 [[0.823346 0.176654]] Approval 0.764 0.47401865434646606
# Number of Inputs:30
# 0 [[0.8620233  0.13797675]] Approval 0.76 0.48055180835723876
# Number of Inputs:30
# 0 [[0.8603579  0.13964209]] Approval 0.768 0.47937137937545776
# Number of Inputs:30
# 0 [[0.9210978  0.07890224]] Approval 0.776 0.4708719894886017
# Number of Inputs:30
# 0 [[0.6596344  0.34036553]] Declined 0.736 0.4864636263847351
# Number of Inputs:30
# 1 [[0.2910511 0.7089489]] Declined 0.768 0.48755043125152586
# Number of Inputs:30
# 0 [[0.4280201  0.57197994]] Declined 0.772 0.4861198194026947
# Number of Inputs:30
# 1 [[0.59478086 0.40521917]] Approval 0.776 0.4614942851066589
# Number of Inputs:30
# 0 [[0.97950226 0.02049773]] Approval 0.752 0.4859005079269409
# Number of Inputs:30
# 0 [[0.96107596 0.03892404]] Declined 0.744 0.49762740039825437
# Number of Inputs:30
# 1 [[0.8292884  0.17071156]] Approval 0.772 0.4614237487316132
# Number of Inputs:30
# 0 [[0.79185534 0.20814468]] Declined 0.748 0.4763693287372589
# Number of Inputs:30
# 0 [[0.82447505 0.17552498]] Declined 0.724 0.4980661251544952
# Number of Inputs:30
# 1 [[0.11120109 0.88879895]] Declined 0.768 0.47368687915802005
# Number of Inputs:30
# 0 [[0.8710158  0.12898429]] Approval 0.768 0.47730559277534484
# Number of Inputs:30
# 0 [[0.7583973  0.24160281]] Approval 0.784 0.4643771312236786
# Number of Inputs:30
# 0 [[0.79439145 0.20560858]] Approval 0.756 0.47293686580657956
# Number of Inputs:30
# 0 [[0.8069466  0.19305341]] Approval 0.772 0.4685643663406372

# %% [markdown]
# # Model Evaluations

# %%
# Confusion Matrix Averages Equivilent
tests_df.groupby(['Actual', 'Result']).mean()
# Out:
#                  Approval_Prob        MA        ML
# Actual Result
# 0      Approval       0.826081  0.771600  0.474351
#        Declined       0.703013  0.751467  0.485520
# 1      Approval       0.619114  0.767556  0.472745
#        Declined       0.293893  0.766750  0.475123

# %%
# General Data Evaluation
tests_df.describe()
# Out:
#        Approval_Prob          MA          ML
# count     100.000000  100.000000  100.000000
# mean        0.703843    0.767440    0.476006
# std         0.245941    0.014815    0.010231
# min         0.111201    0.720000    0.450182
# 25%         0.546432    0.760000    0.470844
# 50%         0.793123    0.768000    0.475009
# 75%         0.904616    0.776000    0.481511
# max         0.989195    0.800000    0.504180

# %%
# Confusion Matrix Equivilent
tests_df.groupby(['Actual', 'Result']).count()
# Out:
#                  Approval_Prob  MA  ML
# Actual Result
# 0      Approval             60  60  60
#        Declined             15  15  15
# 1      Approval              9   9   9
#        Declined             16  16  16

# %% [markdown]
# # Model Variable Evaluation
# Testing number of nodes, layers, and epochs to get best model

# %%
'''
Credit Crunch
Author: Andrew McKinney
Creation Date: 2020-04-28
'''

import numpy as np
import warnings
warnings.filterwarnings("ignore")

print(f'''layers, nodes, epochs: accuracy''')

max_layers = 5
max_nodes = 90
max_epochs = 100

# results_df = pd.DataFrame(columns={'Accuracy', 'Loss', 'Layers', 'Nodes', 'Epochs'})

for num_lays in np.arange(1, max_layers + 1):

    for num_nodes in np.arange(10, max_nodes + 1, 20):
        
        for num_epochs in np.arange(10, max_epochs + 1, 20):
            
            ### DEV TOOLS ###
            numpy_seed = 42
            number_inputs = 30
            number_classes = 2
            number_hidden_layers = num_lays
            number_hidden_nodes = num_nodes
            number_epochs = num_epochs
            layer_activation = 'relu'
            classifier_activation = 'softmax'
            learn_metrics = ['accuracy']
            loss_type = 'categorical_crossentropy'
            optimizer_type = 'adam'

            # import dependencies
            import numpy as np
            import pandas as pd
            from sklearn.model_selection import train_test_split
            from sklearn.preprocessing import LabelEncoder, MinMaxScaler
            from tensorflow.keras.utils import to_categorical
            from tensorflow.keras.models import Sequential
            from tensorflow.keras.layers import Dense



            # setting numpy seed for reproducible results
            np.random.seed(numpy_seed)


            # import train data
            raw_data = pd.read_csv('datasets/Credit_Data_Raw.csv')

            raw_data.dropna()

            # defining labels, input fields, and input form data
            X = raw_data.drop('DEFAULT', axis=1)
            y = np.array(raw_data['DEFAULT']).reshape(-1, 1)

            # spliting data to test and training sets
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)


            # scaling data 
            X_scaler = MinMaxScaler().fit(X_train)
            X_train_scaled = X_scaler.transform(X_train)
            X_test_scaled = X_scaler.transform(X_test)


            # one-hot-encoding output labels
            label_encoder = LabelEncoder()
            label_encoder.fit(y_train)
            encoded_y_train = label_encoder.transform(y_train)
            encoded_y_test = label_encoder.transform(y_test)
            y_train_categorical = to_categorical(encoded_y_train)
            y_test_categorical = to_categorical(encoded_y_test)

            # instantiating Neural Net Model
            model = Sequential()

            # adding input layer
            model.add(Dense(units=number_hidden_nodes, activation=layer_activation, input_dim=number_inputs))

            # adding hidden layers
            for layer in np.arange(0, number_hidden_layers):
                model.add(Dense(units=number_hidden_nodes, activation=layer_activation))

            # adding classifier layer
            model.add(Dense(units=number_classes, activation=classifier_activation))

            # compiling model
            model.compile(optimizer=optimizer_type, loss=loss_type, metrics=learn_metrics)

            # fitting model to training data
            model.fit(
                X_train_scaled,
                y_train_categorical,
                epochs=number_epochs,
                shuffle=True,
                verbose=0
            )


            model_eval = model.evaluate(X_test_scaled, y_test_categorical, verbose=0)
            model_accuracy = model_eval[1]
            model_loss = model_eval[0]
            
            print(f'''{num_lays}, {num_nodes}, {num_epochs}: {model_accuracy}''')
        
            current_result = pd.DataFrame({'Accuracy':[model_accuracy], 'Loss':[model_loss], 'Layers':[num_lays], 'Nodes':[num_nodes], 'Epochs':[num_epochs]})
            results_df = results_df.append(current_result)
            
            results_df.to_csv('datasets/NN_Evaluation.csv')
# Out:
# layers, nodes, epochs: accuracy
# 1, 10, 10: 0.7160000205039978
# 1, 10, 30: 0.7680000066757202
# 1, 10, 50: 0.7799999713897705
# 1, 10, 70: 0.7480000257492065
# 1, 10, 90: 0.7239999771118164
# 1, 30, 10: 0.7519999742507935
# 1, 30, 30: 0.7599999904632568
# 1, 30, 50: 0.7239999771118164
# 1, 30, 70: 0.7599999904632568
# 1, 30, 90: 0.7440000176429749
# 1, 50, 10: 0.7599999904632568
# 1, 50, 30: 0.7760000228881836
# 1, 50, 50: 0.7239999771118164
# 1, 50, 70: 0.7480000257492065
# 1, 50, 90: 0.7239999771118164
# 1, 70, 10: 0.7720000147819519
# 1, 70, 30: 0.7680000066757202
# 1, 70, 50: 0.7559999823570251
# 1, 70, 70: 0.7239999771118164
# 1, 70, 90: 0.7039999961853027
# 1, 90, 10: 0.7400000095367432
# 1, 90, 30: 0.7480000257492065
# 1, 90, 50: 0.6840000152587891
# 1, 90, 70: 0.7080000042915344
# 1, 90, 90: 0.671999990940094
# 2, 10, 10: 0.7239999771118164
# 2, 10, 30: 0.7519999742507935
# 2, 10, 50: 0.7599999904632568
# 2, 10, 70: 0.7799999713897705
# 2, 10, 90: 0.7400000095367432
# 2, 30, 10: 0.7639999985694885
# 2, 30, 30: 0.7519999742507935
# 2, 30, 50: 0.6959999799728394
# 2, 30, 70: 0.7200000286102295
# 2, 30, 90: 0.6959999799728394
# 2, 50, 10: 0.7680000066757202
# 2, 50, 30: 0.7319999933242798
# 2, 50, 50: 0.7039999961853027
# 2, 50, 70: 0.7400000095367432
# 2, 50, 90: 0.7480000257492065
# 2, 70, 10: 0.7319999933242798
# 2, 70, 30: 0.7160000205039978
# 2, 70, 50: 0.6840000152587891
# 2, 70, 70: 0.7400000095367432
# 2, 70, 90: 0.7440000176429749
# 2, 90, 10: 0.7279999852180481
# 2, 90, 30: 0.7279999852180481
# 2, 90, 50: 0.6959999799728394
# 2, 90, 70: 0.699999988079071
# 2, 90, 90: 0.7239999771118164
# 3, 10, 10: 0.7120000123977661
# 3, 10, 30: 0.7360000014305115
# 3, 10, 50: 0.7720000147819519
# 3, 10, 70: 0.7360000014305115
# 3, 10, 90: 0.7239999771118164
# 3, 30, 10: 0.7559999823570251
# 3, 30, 30: 0.7519999742507935
# 3, 30, 50: 0.7239999771118164
# 3, 30, 70: 0.7400000095367432
# 3, 30, 90: 0.7519999742507935
# 3, 50, 10: 0.7639999985694885
# 3, 50, 30: 0.7360000014305115
# 3, 50, 50: 0.7519999742507935
# 3, 50, 70: 0.7400000095367432
# 3, 50, 90: 0.6959999799728394
# 3, 70, 10: 0.7599999904632568
# 3, 70, 30: 0.7200000286102295
# 3, 70, 50: 0.6959999799728394
# 3, 70, 70: 0.7400000095367432
# 3, 70, 90: 0.7039999961853027
# 3, 90, 10: 0.7519999742507935
# 3, 90, 30: 0.7120000123977661
# 3, 90, 50: 0.7400000095367432
# 3, 90, 70: 0.7239999771118164
# 3, 90, 90: 0.7200000286102295
# 4, 10, 10: 0.7440000176429749
# 4, 10, 30: 0.7480000257492065
# 4, 10, 50: 0.7519999742507935
# 4, 10, 70: 0.7519999742507935
# 4, 10, 90: 0.7639999985694885
# 4, 30, 10: 0.7480000257492065
# 4, 30, 30: 0.7039999961853027
# 4, 30, 50: 0.7319999933242798
# 4, 30, 70: 0.7200000286102295
# 4, 30, 90: 0.6759999990463257
# 4, 50, 10: 0.7639999985694885
# 4, 50, 30: 0.6959999799728394
# 4, 50, 50: 0.6480000019073486
# 4, 50, 70: 0.7360000014305115
# 4, 50, 90: 0.6919999718666077
# 4, 70, 10: 0.7519999742507935
# 4, 70, 30: 0.6679999828338623
# 4, 70, 50: 0.7360000014305115
# 4, 70, 70: 0.7319999933242798
# 4, 70, 90: 0.7120000123977661
# 4, 90, 10: 0.7559999823570251
# 4, 90, 30: 0.7319999933242798
# 4, 90, 50: 0.7239999771118164
# 4, 90, 70: 0.7599999904632568
# 4, 90, 90: 0.7239999771118164
# 5, 10, 10: 0.7559999823570251
# 5, 10, 30: 0.7599999904632568
# 5, 10, 50: 0.7440000176429749
# 5, 10, 70: 0.7120000123977661
# 5, 10, 90: 0.7519999742507935
# 5, 30, 10: 0.7680000066757202
# 5, 30, 30: 0.7200000286102295
# 5, 30, 50: 0.7319999933242798
# 5, 30, 70: 0.7080000042915344
# 5, 30, 90: 0.7279999852180481
# 5, 50, 10: 0.7559999823570251
# 5, 50, 30: 0.7400000095367432
# 5, 50, 50: 0.7360000014305115
# 5, 50, 70: 0.7200000286102295
# 5, 50, 90: 0.7080000042915344
# 5, 70, 10: 0.699999988079071
# 5, 70, 30: 0.7039999961853027
# 5, 70, 50: 0.7440000176429749
# 5, 70, 70: 0.7440000176429749
# 5, 70, 90: 0.7559999823570251
# 5, 90, 10: 0.7919999957084656
# 5, 90, 30: 0.7039999961853027
# 5, 90, 50: 0.7599999904632568
# 5, 90, 70: 0.7239999771118164
# 5, 90, 90: 0.7239999771118164

# %%
# Sorting through Accuracy and Loss for Optimal Inputs
results_df.sort_values('Loss', ascending=False)
# Out:
#     Accuracy Epochs Layers      Loss Nodes
# 0      0.676     90      4  3.633299    30
# 0      0.724     70      5  3.270233    90
# 0      0.720     90      5  3.106154    50
# 0      0.712     90      4  3.041902    70
# 0      0.700     90      4  2.917255    70
# ..       ...    ...    ...       ...   ...
# 0      0.756     10      3  0.477906    30
# 0      0.756     30      1  0.473475    10
# 0      0.772     10      1  0.472219    70
# 0      0.752     10      3  0.470935    30
# 0      0.780     10      1  0.467232    50
#
# [250 rows x 5 columns]

# %%
# Grouping by Inputs (Nodes, Layers, Epochs) for Accuracy and Loss
results_df.groupby(['Nodes']).mean()
# Out:
#        Accuracy      Loss
# Nodes
# 10      0.74480  0.567095
# 30      0.73424  1.212214
# 50      0.72888  1.514524
# 70      0.72720  1.605138
# 90      0.72736  1.719060
